# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan dan Penggunaan Operator pada Phyton”**
#
# **Disusun Oleh :**
#
# **Malika Azizah Muskhir**
#
# **2611532022**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Allah SWT atas rahmat dan karunia-Nya sehingga penulis dapat menyelesaikan laporan praktikum Python yang berjudul “Pengenalan dan Penggunaan Operator pada Python” dengan baik.
#
# Laporan ini disusun untuk memenuhi tugas praktikum serta menambah pemahaman mengenai penggunaan berbagai operator dalam bahasa pemrograman Python, seperti operator aritmatika, perbandingan, logika, assignment, bitwise, dan operator lainnya.
#
# Penulis mengucapkan terima kasih kepada dosen pengampu mata kuliah praktikum yang telah memberikan arahan, bimbingan, dan pengetahuan selama proses pembelajaran. Penulis juga mengucapkan terima kasih kepada semua pihak yang telah membantu dalam pelaksanaan praktikum.
#
# Penulis menyadari bahwa laporan ini masih jauh dari sempurna, baik dari segi isi maupun penyusunannya. Oleh karena itu, penulis mengharapkan kritik dan saran yang membangun dari pembaca sebagai bahan evaluasi untuk memperbaiki laporan di masa mendatang.
#
# Akhir kata, penulis berharap semoga laporan praktikum ini dapat memberikan manfaat bagi penulis maupun pembaca, serta menjadi referensi dalam memahami dan mempelajari dasar-dasar pemrograman Python, khususnya mengenai penggunaan berbagai jenis operator.
# <div align = "right">
# Padang, 18 September, 2026
# <br><br><br>
# Malika Azizah Muskhir

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi yang semakin pesat menjadikan pemrograman komputer sebagai salah satu keterampilan yang penting untuk dipelajari. Salah satu bahasa pemrograman yang banyak digunakan adalah Python. Python memiliki sintaks yang sederhana dan mudah dipahami sehingga cocok digunakan oleh pemula untuk mempelajari dasar-dasar pemrograman.
#
# Dalam pemrograman Python, operator merupakan salah satu komponen dasar yang memiliki peranan penting dalam menjalankan berbagai instruksi. Operator digunakan untuk melakukan operasi terhadap nilai maupun variabel, seperti perhitungan matematika, perbandingan nilai, pengolahan kondisi logika, serta manipulasi data dalam bentuk biner.
#
# Terdapat beberapa jenis operator dalam Python, di antaranya operator aritmatika, perbandingan, logika, assignment, bitwise, serta operator lainnya seperti membership dan identity. Setiap operator memiliki fungsi dan cara penggunaan yang berbeda sesuai dengan kebutuhan program.
#
# Oleh karena itu, praktikum ini dilaksanakan untuk mempelajari dan memahami penggunaan berbagai jenis operator dalam bahasa pemrograman Python. Melalui kegiatan praktikum ini, mahasiswa diharapkan mampu menerapkan operator dengan tepat dalam pembuatan program sederhana serta meningkatkan pemahaman terhadap konsep dasar pemrograman.
#
# ## 1.2 Tujuan
# 1. Memahami pengertian dan fungsi operator dalam bahasa pemrograman Python.
# 2. Mengetahui jenis-jenis operator yang terdapat dalam Python.
# 3. Mampu menerapkan berbagai jenis operator dalam pembuatan program sederhana menggunakan Python.
#
# ## 1.3 Manfaat
# 1. Menambah pengetahuan dan pemahaman mengenai dasar-dasar pemrograman Python.
# 2. Memahami fungsi dan penggunaan berbagai jenis operator dalam Python.
# 3. Mengembangkan kemampuan berpikir logis dan sistematis dalam menyelesaikan permasalahan.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Operator adalah simbol atau kata khusus yang digunakan untuk melakukan operasi terhadap nilai atau variabel. Dalam Python, operator berfungsi untuk melakukan perhitungan, membandingkan nilai, mengolah kondisi logika, serta memanipulasi data. Operator memiliki beberapa jenis dengan fungsi yang berbeda-beda.
# 1. Operator Aritmatika
#
# Operator aritmatika digunakan untuk melakukan operasi matematika, seperti penjumlahan, pengurangan, perkalian, dan pembagian. Operator ini juga dapat digunakan untuk menghitung sisa bagi, perpangkatan, dan pembagian bulat.
#
# 2. Operator Perbandingan
#
# Operator perbandingan digunakan untuk membandingkan dua nilai atau variabel. Hasil dari operasi perbandingan berupa nilai Boolean, yaitu True jika kondisi benar dan False jika kondisi salah.
#
# 3. Operator Logika
#
# Operator logika digunakan untuk menggabungkan atau membalik kondisi logika. Operator ini terdiri dari and, or, dan not, yang digunakan untuk menentukan hasil berdasarkan kondisi tertentu
#
# 4. Operator Assignment
#
# Operator assignment digunakan untuk memberikan nilai kepada variabel atau memperbarui nilai variabel yang sudah ada. Contohnya adalah =, +=, -=, *=, dan /=. Operator ini dapat mempermudah penulisan kode program.
#
# 5. Operator Bitwise
#
# Operator bitwise digunakan untuk melakukan operasi terhadap bilangan dalam bentuk biner. Operator ini meliputi AND (&), OR (|), XOR (^), NOT (~), shift kiri (<<), dan shift kanan (>>).
#
# 6. Operator Lainnya
#
# Selain operator yang telah dijelaskan, Python memiliki operator membership dan identity. Operator membership (in dan not in) digunakan untuk memeriksa keberadaan suatu nilai dalam kumpulan data. Sementara itu, operator identity (is dan is not) digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Operator Aritmatika "B_2611532022"

# %%
# Buat file dengan nama aritmatika_2611532022.py
# Buat program untuk operator arotmatika dalam phyton
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan input ()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_2022 = int(input("input angka-1:"))
angka2_2022 = int(input("input angka-2:"))

# penjumlahan
hasil = angka1_2022 + angka2_2022
print("\nOperator Penjumlahan:")
print("Hasil =", hasil)

# pengurangan
hasil = angka1_2022 - angka2_2022
print("\nOperator Pengurangan:")
print("Hasil =", hasil)

# perkalian
hasil = angka1_2022 * angka2_2022
print("\nOperator Perkalian:")
print("Hasil =", hasil)

# pembagian
if angka2_2022 != 0:
    hasil = angka1_2022 / angka2_2022
    print("\nOperator Pembagian:")
    print("Hasil =", hasil)

    hasil = angka1_2022 // angka2_2022
    print("\nOperasi Pembagian Bulat:")
    print("Hasil =", hasil)

    hasil = angka1_2022 % angka2_2022
    print("\nOperator Sisa Bagi:")
    print("Hasil =", hasil)
else:
    print("Angka kedua tidak boleh bernilai 0")

# Pangkat
hasil = angka1_2022 ** angka2_2022
print("\nOperator Pangkat:")
print("Hasil =", hasil)

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi `input()` digunakan untuk meminta pengguna memasukkan dua angka sebagai data yang akan diolah.
# 2. Fungsi `int()` digunakan untuk mengubah data input menjadi tipe data bilangan bulat (integer).
# 3. Operator `+` digunakan untuk menjumlahkan dua angka yang dimasukkan oleh pengguna.
# 4. Operator `-` digunakan untuk menghitung selisih antara dua angka.
# 5. Operator `*` digunakan untuk mengalikan dua angka.
# 6. Operator `/` digunakan untuk membagi dua angka dan menghasilkan nilai berupa desimal.
# 7. Operator `//` digunakan untuk melakukan pembagian dan membulatkan hasilnya ke bawah.
# 8. Operator `%` digunakan untuk memperoleh sisa hasil pembagian dua angka.
# 9. Kondisi `if` dan `else` digunakan untuk memeriksa apakah angka kedua bernilai nol. Jika angka kedua bernilai nol, program akan menampilkan pesan bahwa angka kedua tidak boleh bernilai nol.
# 10. Operator `**` digunakan untuk menghitung hasil perpangkatan angka pertama dengan angka kedua.
# 11. Fungsi `print()` digunakan untuk menampilkan hasil operasi dan keterangan pada layar.

# %% [markdown]
# ### 2.2.2 Operator Perbandingan "B_2611532022"

# %%
# Buat file dengan nama perbandingan_2611532022.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menngunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_2022 = int(input("Input angka-1: "))
angka2_2022 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_2022 = angka1_2022 > angka2_2022
print("\nOperator lebih besar dari")
print("angka1_2022 > angka2_2022 =",hasil_2022)

# Lebih kecil dari
hasil_2022 = angka1_2022 < angka2_2022
print("\nOperator lebih kecil dari")
print("angka1_2022 < angka2_2022 =",hasil_2022)

# Lebih besar dari atau sama dengan
hasil_2022 = angka1_2022 >= angka2_2022
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_2022 >= angka2_2022 =",hasil_2022)

# Lebih kecil dari atau sama dengan
hasil_2022 = angka1_2022 <= angka2_2022
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1_2022 <= angka2_2022 =",hasil_2022)

# Sama dengan
hasil_2022 = angka1_2022 == angka2_2022
print("\nOperator sama dengan")
print("angka1_2022 == angka2_2022 =",hasil_2022)

# Tidak sama dengan
hasil_2022 = angka1_2022 != angka2_2022
print("\nOperator tidak sama dengan")
print("angka1_2022 != angka2_2022 =",hasil_2022)

# Tambahan: perbandingan berantai dalam Python
hasil_2022 = 0 < angka1_2022 < 100
print("\nPerbandingan berantai")
print("0 < angka1_1022 < 100 =",hasil_2022)

hasil_2022 = 0 < angka2_2022 < 100
print("0 < angka2_1022 < 100 =",hasil_2022)

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi input() digunakan untuk meminta pengguna memasukkan dua angka sebagai data yang akan dibandingkan.
# 2. Fungsi int() digunakan untuk mengubah data input menjadi tipe data bilangan bulat (integer).
# 3. Operator > digunakan untuk membandingkan apakah angka pertama lebih besar daripada angka kedua.
# 4. Operator < digunakan untuk membandingkan apakah angka pertama lebih kecil daripada angka kedua.
# 5. Operator >= digunakan untuk memeriksa apakah angka pertama lebih besar atau sama dengan angka kedua.
# 6. Operator <= digunakan untuk memeriksa apakah angka pertama lebih kecil atau sama dengan angka kedua.
# 7. Operator == digunakan untuk memeriksa apakah kedua angka memiliki nilai yang sama.
# 8. Operator != digunakan untuk memeriksa apakah kedua angka memiliki nilai yang berbeda.
# 9. Operator perbandingan berantai (0 < angka < 100) digunakan untuk memeriksa apakah nilai angka berada di antara 0 dan 100, tanpa menyertakan kedua batas tersebut.
# 10. Variabel hasil_2022 digunakan untuk menyimpan hasil perbandingan dalam bentuk nilai Boolean, yaitu True atau False.
# 11. Fungsi print() digunakan untuk menampilkan keterangan operator dan hasil perbandingan ke layar.

# %% [markdown]
# ### 2.2.3 Operator Logika "B_2611532022"

# %%
# Buat file dengan nama Logika_2611532022.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan input ()
# Program operator logika dalah Phyton

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_2022 = input("Masukkan nilai boolean-1_2022 (True/False):")
a2_2022 = input("Masukkan nilai boolean-2_2022 (True/False):")

print("\nA1_2022 =", a1_2022)
print("A2_2022 =", a2_2022)

# Konjungsi: bernilai True jika keduanya True
hasil = a1_2022 and a2_2022
print("\nKonjungsi (AND):")
print("A1_2022 and A2_2022 =", hasil)

# Disjungsi: bernilai True jika salah satunya True
hasil = a1_2022 or a2_2022
print("\nDisjungsi (OR):")
print("A1_2022 or A2_2022 =", hasil)

# Negasi A1: membalik nilai A1
hasil = not a1_2022
print("\nNegasi A1_2022 (NOT):")
print(" not A1_2022 =", hasil)

# Negasi A2: membalik nilai A2
hasil = not a2_2022
print("\nNegasi A2_2022 (NOT):")
print(" not A2_2022 =", hasil)

# XOR: bernilai True jika nilai keduanya berbeda
hasil = a1_2022 != a2_2022
print("\nDisjungsi Ekslusif (XOR):")
print("A1_2022 XOR A2_2022 =", hasil)

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi input() digunakan untuk meminta pengguna memasukkan dua nilai Boolean, yaitu True atau False.
# 2. Variabel a1_2022 dan a2_2022 digunakan untuk menyimpan nilai yang dimasukkan oleh pengguna.
# 3. Fungsi print() digunakan untuk menampilkan nilai variabel dan hasil operasi logika ke layar.
# 4. Operator and (AND) digunakan untuk menghasilkan nilai True jika kedua kondisi bernilai benar.
# 5. Operator or (OR) digunakan untuk menghasilkan nilai True jika salah satu atau kedua kondisi bernilai benar.
# 6. Operator not (NOT) digunakan untuk membalik nilai logika, yaitu True menjadi False dan sebaliknya.
# 7. Operator != digunakan dalam operasi XOR untuk menghasilkan nilai True jika kedua nilai berbeda dan False jika kedua nilai sama.

# %% [markdown]
# ### 2.2.4 Operator Assignment "B_2611532022"

# %%
# Buat file dengan nama assignment_2611532022.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan input ()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Phyton

angka1_2022 = int(input("input angka-1_2022: "))
angka2_2022 = int(input("input angka-2_2022: "))

print("\nNilai awal angka1_2022 =", angka1_2022)
print("Nilai awal angka2_2022 =", angka2_2022)

# Assignment biasa
hasil = angka1_2022
print("\nAssignment biasa:")
print("hasil =", hasil)

# Assignment penambahan
hasil = angka1_2022
hasil += angka2_2022
print("\nAssignment penambahan (+=):")
print("hasil =", hasil)

# Assignment pengurangan
hasil = angka1_2022
hasil -= angka2_2022
print("\nAssignment pengurangan (-=):")
print("hasil =", hasil)

# Assignment perkalian
hasil = angka1_2022
hasil *= angka2_2022
print("\nAssignment perkalian (*=):")
print("hasil =", hasil)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2022 !=0:
    hasil = angka1_2022
    hasil /= angka2_2022
    print("\nAssignment pembagian (/=):")
    print("hasil =", hasil)
    # Operator tambahan
    hasil = angka1_2022
    hasil //= angka2_2022
    print("\nAssignment pembagian bulat (//=):")
    print("hasil =", hasil)
    # Sisa bagi
    hasil = angka1_2022
    hasil %= angka2_2022
    print("\nAssignment sisa bagi (%=):")
    print("hasil =", hasil)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0")

# Operator tambahan: assignment perpangkatan
hasil = angka1_2022
hasil **= angka2_2022
print("\nAssignment perpangkatan (**=):")
print("hasil =", hasil)

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi input() digunakan untuk meminta pengguna memasukkan dua angka yang akan digunakan dalam operasi assignment.
# 2. Fungsi int() digunakan untuk mengubah nilai input menjadi tipe data bilangan bulat (integer).
# 3. Variabel angka1_2022 dan angka2_2022 digunakan untuk menyimpan dua angka yang dimasukkan oleh pengguna.
# 4. Operator = digunakan untuk memberikan nilai dari variabel angka1_2022 ke variabel hasil.
# 5. Operator += digunakan untuk menambahkan nilai angka2_2022 ke hasil dan menyimpan hasilnya kembali ke variabel tersebut.
# 6. Operator -= digunakan untuk mengurangi nilai hasil dengan angka2_2022 dan menyimpan hasil pengurangan.
# 7. Operator *= digunakan untuk mengalikan nilai hasil dengan angka2_2022 dan menyimpan hasil perkalian.
# 8. Operator /= digunakan untuk membagi nilai hasil dengan angka2_2022 dan menyimpan hasil pembagian.
# 9. Operator //= digunakan untuk melakukan pembagian bulat dan menyimpan hasil pembagian ke variabel hasil.
# 10. Operator %= digunakan untuk menghitung dan menyimpan sisa hasil pembagian.
# 11. Operator **= digunakan untuk menghitung perpangkatan angka pertama dengan angka kedua dan menyimpan hasilnya.
# 12. Kondisi if dan else digunakan untuk memeriksa apakah angka kedua bernilai nol sebelum melakukan operasi pembagian. Jika bernilai nol, program menampilkan pesan bahwa pembagian tidak dapat dilakukan.
# 13. Fungsi print() digunakan untuk menampilkan nilai awal variabel dan hasil dari setiap operasi assignment ke layar.

# %% [markdown]
# ### 2.2.5 Operator Bitwise "B_2611532022"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1008
# Program ini menggunakan fungsi input()

print("======================================")
print("3. OPERATOR BITWISE")
print("======================================")

angka1_2022 = int(input("Masukkan angka bitwise-1: "))
angka2_2022 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =",angka1_2022,"| biner =",bin(angka1_2022))
print("angka1 =",angka2_2022,"| biner =",bin(angka2_2022))

# Bitwise AND
hasil_2022 = angka1_2022 & angka2_2022
print("\nBitwise AND (&)")
print(angka1_2022,"&",angka2_2022,hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# Bitwise OR
hasil_2022 = angka1_2022 | angka2_2022
print("\nBitwise OR (|)")
print(angka1_2022,"|",angka2_2022,hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# Bitwise XOR
hasil_2022 = angka1_2022 ^ angka2_2022
print("\nBitwise XOR (^)")
print(angka1_2022,"^",angka2_2022,hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# Bitwise NOT
hasil_2022 = ~angka1_2022
print("\nBitwise NOT (~)")
print(angka1_2022,"~",angka2_2022,hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# Bitwise geser kiri
jumlah_geser_2022 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2022 = angka1_2022 << jumlah_geser_2022
print("\nBitwise geser kiri (<<)")
print(angka1_2022,"<<",jumlah_geser_2022,"=",hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# Bitwise geser kanan
hasil_2022= angka1_2022 >> jumlah_geser_2022
print("\nBitwise geser kanan (>>)")
print(angka1_2022,">>",jumlah_geser_2022,"=",hasil_2022)
print("Biner hasil =",bin(hasil_2022))
print("Biner hasil (8 bit) =",format(hasil_2022,"08b"))

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi print() digunakan untuk menampilkan judul dan keterangan program operator bitwise.
# 2. Fungsi input() digunakan untuk meminta pengguna memasukkan dua angka dan jumlah pergeseran bit.
# 3. Fungsi int() digunakan untuk mengubah nilai input menjadi tipe data bilangan bulat (integer).
# 4. Fungsi bin() digunakan untuk mengubah bilangan desimal menjadi bilangan biner.
# 5. Operator & (AND) digunakan untuk membandingkan setiap bit dari dua bilangan. Hasil bit bernilai 1 jika kedua bit bernilai 1.
# 6. Operator | (OR) digunakan untuk membandingkan setiap bit dari dua bilangan. Hasil bit bernilai 1 jika salah satu atau kedua bit bernilai 1.
# 7. Operator ^ (XOR) digunakan untuk membandingkan setiap bit dari dua bilangan. Hasil bit bernilai 1 jika kedua bit berbeda.
# 8. Operator ~ (NOT) digunakan untuk membalik setiap bit dari suatu bilangan, yaitu 0 menjadi 1 dan 1 menjadi 0.
# 9. Operator << (geser kiri) digunakan untuk menggeser bit ke arah kiri sesuai jumlah pergeseran yang ditentukan.
# 10. Operator >> (geser kanan) digunakan untuk menggeser bit ke arah kanan sesuai jumlah pergeseran yang ditentukan.
# 11. Fungsi format() digunakan untuk menampilkan hasil bilangan biner dengan panjang minimal 8 bit menggunakan format "08b".
# 12. Variabel hasil_2022 digunakan untuk menyimpan hasil dari setiap operasi bitwise sebelum ditampilkan ke layar

# %% [markdown]
# ### 2.2.6 Operator Lainnya "B_2611532022"

# %%
# Buat file dengan nama Lainnya_2611532022.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input ()
# Program operator keanggotan dan identitas

print("===========================================")
print("1. Operator Keanggotaan")
print("===========================================")

# Input beberapa data yang dipisahkan dengan koma
input_data = input("Masukkan beberapa angka, pisahkan dengan koma:")

# Mengubah input menjadi list integer
data = [int(angka.strip()) for angka in input_data.split(",")]

nilai_dicari = int(input("Masukkan nilai yang dicari:"))

# Operator in
hasil = nilai_dicari in data
print("\nOperator keanggotaan IN")
print("nilai_dicari, "in" data =", hasil)

# Operator not in
hasil = nilai_dicari not in data
print("\nOperator keanggotaan NOT IN")
print("nilai_dicari, "not in" data =", hasil)

print("\n===========================================")
print("2. Operator Identitas")
print("===========================================")

# objek1_2022 menggunakan list dari input pengguna
objek1_2022 = data

# objek2_2022 menggunakan list yang sama dengan objek1_2022
objek2_2022 = objek1_2022

# objek3_2022 menmiliki isi yang sama, tetapi merupakan objek yang berbeda
objek3_2022 = data.copy()

print("objek1_2022 =", objek1_2022)
print("objek2_2022 =", objek2_2022)
print("objek3_2022 =", objek3_2022)

#operator is
hasil = objek1_2022 is objek2_2022
print("\nOperator identotas IS")
print("objek1_2022 is objek2_2022 =", hasil)

#operator is not 
hasil = objek1_2022 is not objek3_2022
print("\nOperator identotas IS NOT")
print("objek1_2022 is not objek3_2022 =", hasil)

# Membandingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai: ")
print("Objek1_2022 is objek3_2022=", objek1_2022 is objek3_2022)
print("Objek1_2022 == objek3_2022=", objek1_2022 == objek3_2022)

# %% [markdown]
# **Penjelasan :**
# 1. Fungsi print() digunakan untuk menampilkan judul dan keterangan program operator keanggotaan dan identitas.
# 2. Fungsi input() digunakan untuk meminta pengguna memasukkan beberapa angka dan nilai yang ingin dicari.
# 3. Fungsi split(",") digunakan untuk memisahkan data input berdasarkan tanda koma.
# 4. Fungsi strip() digunakan untuk menghapus spasi yang terdapat di awal dan akhir data.
# 5. Fungsi int() digunakan untuk mengubah data input menjadi tipe bilangan bulat (integer).
# 6. Operator in digunakan untuk memeriksa apakah nilai yang dicari terdapat dalam sebuah list. Jika ditemukan, hasilnya True.
# 7. Operator not in digunakan untuk memeriksa apakah nilai yang dicari tidak terdapat dalam sebuah list. Jika tidak ditemukan, hasilnya True.
# 8. Variabel objek1_2022 digunakan untuk menyimpan list data yang dimasukkan oleh pengguna.
# 9. Variabel objek2_2022 digunakan untuk merujuk pada objek list yang sama dengan objek1_2022.
# 10. Fungsi copy() digunakan untuk membuat salinan list dengan isi yang sama, tetapi sebagai objek yang berbeda.
# 11. Operator is digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.
# 12. Operator is not digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang berbeda.
# 13. Operator == digunakan untuk membandingkan apakah isi atau nilai dari dua objek sama, tanpa harus merujuk pada objek yang sama.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/tugas3.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program Tugas3 "B_2611532022"

# %%
# Buat file dengan nama Tugas3_2611532022.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input ()
# Program operator Sistem Simulasi Transaksi dan Validasi Akses Toko

# 1. INPUT DATA PELANGGAN
nama_2022 = input("Masukkan nama pelanggan: ")
status_2022 = input("Masukkan status (member/nonmember): ")
jumlah_2022 = int(input("Masukkan jumlah barang: "))
harga_2022 = int(input("Masukkan harga satu barang: "))
promo_2022 = input("Masukkan kode promo (HEMAT10/HEMAT20/GRATISONGKIR): ")

# 2. OPERASI ARITMATIKA
belanja_2022 = jumlah_2022 * harga_2022

# Menghitung rata-rata harga per barang
rata_rata_2022 = belanja_2022
if jumlah_2022 > 0:
    rata_rata_2022 /= jumlah_2022

# 3. OPERASI PERBANDINGAN
member_2022 = status_2022 == "member"
belanja_cukup_2022 = belanja_2022 >= 100000
barang_cukup_2022 = jumlah_2022 >= 3
promo_valid_2022 = promo_2022 in ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

# 4. OPERASI LOGIKA
akses_promo_2022 = (
    member_2022
    and belanja_cukup_2022
    and barang_cukup_2022
    and promo_valid_2022
)

akses_toko_2022 = (
    status_2022 == "member"
    or status_2022 == "nonmember"
)

# 5. OPERASI KEANGGOTAAN
daftar_promo_2022 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
promo_tersedia_2022 = promo_2022 in daftar_promo_2022
promo_tidak_tersedia_2022 = promo_2022 not in daftar_promo_2022

# 6. OPERASI IDENTITAS
daftar_promo_2_2022 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
daftar_promo_3_2022 = daftar_promo_2022

identitas_sama_2022 = daftar_promo_2_2022 is daftar_promo_3_2022
identitas_berbeda_2022 = daftar_promo_2_2022 is not daftar_promo_3_2022
isi_sama_2022 = daftar_promo_2_2022 == daftar_promo_3_2022

# 7. OPERASI PENUGASAN
poin_2022 = 0
poin_2022 += jumlah_2022
poin_2022 *= 2

# 8. MENGHITUNG DISKON
diskon_2022 = 0

if akses_promo_2022:
    if promo_2022 == "HEMAT20":
        diskon_2022 = belanja_2022 * 20 // 100
    elif promo_2022 == "HEMAT10":
        diskon_2022 = belanja_2022 * 10 // 100

# Mengurangi total belanja dengan diskon
total_bayar_2022 = belanja_2022
total_bayar_2022 -= diskon_2022

# 9. OPERASI BITWISE
status_bit_2022 = 0

if member_2022:
    status_bit_2022 |= 1

if belanja_cukup_2022:
    status_bit_2022 |= 2

if barang_cukup_2022:
    status_bit_2022 |= 4

if promo_valid_2022:
    status_bit_2022 |= 8

bit_and_2022 = status_bit_2022 & 1
bit_or_2022 = status_bit_2022 | 2
bit_xor_2022 = status_bit_2022 ^ 4

# 10. MENAMPILKAN HASIL
print("\n===== HASIL TRANSAKSI =====")
print("Nama pelanggan:", nama_2022)
print("Status pelanggan:", status_2022)
print("Jumlah barang:", jumlah_2022)
print("Harga satu barang:", harga_2022)
print("Total belanja:", belanja_2022)
print("Rata-rata harga barang:", rata_rata_2022)

print("\n===== VALIDASI =====")
print("Pelanggan adalah member:", member_2022)
print("Belanja minimal Rp100.000:", belanja_cukup_2022)
print("Jumlah barang minimal 3:", barang_cukup_2022)
print("Kode promo valid:", promo_valid_2022)
print("Akses toko:", akses_toko_2022)
print("Akses promo:", akses_promo_2022)

print("\n===== HASIL PEMBAYARAN =====")
print("Diskon:", diskon_2022)
print("Total pembayaran:", total_bayar_2022)
print("Poin pelanggan:", poin_2022)

print("\n===== OPERASI KEANGGOTAAN =====")
print("Promo tersedia:", promo_tersedia_2022)
print("Promo tidak tersedia:", promo_tidak_tersedia_2022)

print("\n===== OPERASI IDENTITAS =====")
print("Objek 2 dan 3 sama:", identitas_sama_2022)
print("Objek 2 dan 3 berbeda:", identitas_berbeda_2022)
print("Isi daftar sama:", isi_sama_2022)

print("\n===== OPERASI BITWISE =====")
print("Status bit:", status_bit_2022)
print("Bitwise AND:", bit_and_2022)
print("Bitwise OR:", bit_or_2022)
print("Bitwise XOR:", bit_xor_2022)

# %% [markdown]
# **Output :**

# %%
Masukkan nama pelanggan: Malika_Azizah_Muskhir
Masukkan status (member/nonmember): member
Masukkan jumlah barang: 3
Masukkan harga satu barang: 50000
Masukkan kode promo (HEMAT10/HEMAT20/GRATISONGKIR): HEMAT20

===== HASIL TRANSAKSI =====
Nama pelanggan: Malika_Azizah_Muskhir
Status pelanggan: member
Jumlah barang: 3
Harga satu barang: 50000
Total belanja: 150000
Rata-rata harga barang: 50000.0

===== VALIDASI =====
Pelanggan adalah member: True
Belanja minimal Rp100.000: True
Jumlah barang minimal 3: True
Kode promo valid: True
Akses toko: True
Akses promo: True

===== HASIL PEMBAYARAN =====
Diskon: 30000
Total pembayaran: 120000
Poin pelanggan: 6

===== OPERASI KEANGGOTAAN =====
Promo tersedia: True
Promo tidak tersedia: False

===== OPERASI IDENTITAS =====
Objek 2 dan 3 sama: True
Objek 2 dan 3 berbeda: False
Isi daftar sama: True

===== OPERASI BITWISE =====
Status bit: 15
Bitwise AND: 1
Bitwise OR: 15
Bitwise XOR: 11

# %% [markdown]
# **Penejelasan :**
#
# 1. Input Data Pelanggan
#
# Program meminta nama, status pelanggan, jumlah barang, harga barang, dan kode promo yang dimasukkan oleh pengguna.
#
# 2. Operasi Aritmatika
#
# Menghitung total belanja dengan mengalikan jumlah barang dan harga satu barang. Program juga menghitung rata-rata harga barang.
#
# 3. Operasi Perbandingan
#
# Memeriksa apakah pelanggan merupakan member, total belanja mencapai Rp100.000, jumlah barang minimal 3, dan kode promo valid. Hasilnya berupa `True` atau `False`.
#
# 4. Operasi Logika
#
# Menggunakan operator `and` dan `or` untuk menentukan apakah pelanggan dapat mengakses toko dan menggunakan promo.
#
# 5. Operasi Keanggotaan
#
# Menggunakan operator `in` dan `not in` untuk memeriksa apakah kode promo terdapat dalam daftar promo yang tersedia.
#
# 6. Operasi Identitas
#
# Menggunakan operator `is`, `is not`, dan `==` untuk membandingkan apakah dua variabel merujuk pada objek yang sama atau memiliki isi yang sama.
#
# 7. Operasi Penugasan
#
# Menggunakan operator seperti `+=`, `*=`, dan `-=` untuk memperbarui nilai variabel, seperti menghitung poin pelanggan dan mengurangi total belanja dengan diskon.
#
# 8. Menghitung Diskon
#
# Jika pelanggan memenuhi syarat promo, program menghitung diskon 10% atau 20% sesuai kode promo. Kode `GRATISONGKIR` tidak mengurangi total belanja dalam simulasi ini.
#
# 9. Operasi Bitwise
#
# Menggunakan operator `|`, `&`, dan `^` untuk menggabungkan atau membandingkan nilai biner sebagai penanda status pelanggan dan transaksi.
#
# 10. Menampilkan Hasil Program
#
# Menampilkan data pelanggan, hasil validasi, total belanja, diskon, total pembayaran, poin, serta hasil operasi keanggotaan, identitas, dan bitwise.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# ## Kesimpulan
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa bahasa pemrograman Python dapat digunakan untuk membuat program sederhana dengan menerapkan berbagai konsep dasar pemrograman. Praktikum ini membahas penggunaan variabel, tipe data, perintah `input()` dan `print()`, serta operator aritmatika, perbandingan, logika, Assignment, Bitwise, dan operator lainnya.
#
# Melalui penerapan konsep-konsep tersebut, program dapat menerima data dari pengguna, mengolah data sesuai instruksi, melakukan perhitungan, memeriksa kondisi, serta membandingkan nilai dan objek. Output yang dihasilkan berupa data yang dimasukkan pengguna, hasil perhitungan, hasil validasi dalam bentuk `True` atau `False`, serta hasil operasi berdasarkan operator yang digunakan.
#
# Dengan praktikum ini, pemahaman mengenai fungsi dan penggunaan berbagai operator Python menjadi lebih baik. Praktikum juga melatih kemampuan dalam menulis kode, memahami alur program, dan menampilkan hasil sesuai dengan perintah yang diberikan. Secara keseluruhan, praktikum ini menjadi dasar untuk memahami dan mempelajari pemrograman Python lebih lanjut.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# 1. Python Software Foundation. (n.d.). Python Documentation. https://docs.python.org/3/
# 2. Python Software Foundation. (n.d.). The Python Tutorial. https://docs.python.org/3/tutorial/
# 3. W3Schools. (n.d.). Python Tutorial. https://www.w3schools.com/python/
# 4. W3Schools. (n.d.). Python Operators. https://www.w3schools.com/python/python_operators.asp
# 5. GeeksforGeeks. (n.d.). Python Programming Language. https://www.geeksforgeeks.org/python-programming-language/
# 6. Programiz. (n.d.). Learn Python Programming. https://www.programiz.com/python-programming
# 7. Downey, A. B. (2015). Think Python: How to Think Like a Computer Scientist (2nd ed.). Green Tea Press. https://greenteapress.com/wp/think-python-2e/
